# %% [markdown]
# <a href="https://colab.research.google.com/github/kousheel05/TASK_AIML-/blob/main/MINI_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student_names = []
subjects = set()
marks = {}
name = input("Enter student name: ")
age = int(input("Enter age: "))
student_names.append(name)
student_info = (name, age)
n = int(input("Enter number of subjects: "))
for i in range(n):
    subject = input("Enter subject name: ")
    mark = int(input("Enter marks: "))
    subjects.add(subject)
    marks[subject] = mark
total = sum(marks.values())
average = total / n
# Report Card
print("\n----- STUDENT REPORT CARD -----")
print("Name :", student_info[0])
print("Age :", student_info[1])
print("Subjects :", subjects)
print("\nMarks:")
for subject, mark in marks.items():
    print(subject, ":", mark)
print("\nTotal Marks :", total)
print("Average Marks :", average)
# Out:
# Enter student name: Kousheel
# Enter age: 22
# Enter number of subjects: 3
# Enter subject name: Maths
# Enter marks: 55
# Enter subject name: Physisc
# Enter marks: 49
# Enter subject name: Chem
# Enter marks: 51
#
# ----- STUDENT REPORT CARD -----
# Name : Kousheel
# Age : 22
# Subjects : {'Maths', 'Physisc', 'Chem'}
#
# Marks:
# Maths : 55
# Physisc : 49
# Chem : 51
#
# Total Marks : 155
# Average Marks : 51.666666666666664
