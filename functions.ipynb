# %% [markdown]
# <a href="https://colab.research.google.com/github/kousheel05/TASK_AIML-/blob/main/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Functions without parameters

# %%
def greet():
  print('welcome')
greet()
# Out:
# welcome

# %%
def add():
  a = int(input('enter the value'))
  b = int(input('enter the value'))
  print('sum =',a+b)
add()
# Out:
# enter the value10
# enter the value10
# sum = 20

# %%
def mul():
   a = int(input('enter the value'))
   b = int(input('enter the value'))
   print('mul =',a*b)
mul()
# Out:
# enter the value5
# enter the value5
# mul = 25

# %% [markdown]
# functions using parameters

# %%
def greet(name):
  print('welcome',name)
a = input('enter your username')
greet(a)
# Out:
# enter your usernamekousheel
# welcome kousheel

# %%
def add(a,b):
  print('sum =',a+b)
num1 = int(input('enter any number'))
num2 = int(input('enter any number'))
add(num1,num2)
# Out:
# enter any number50
# enter any number5
# sum = 55

# %%
def mul(a,b):
  print('mul =',a*b)
a = int(input('enter any number'))
b = int(input('enter any number'))
mul1(a,b)
# Out:
# enter any number10
# enter any number100
# mul = 1000

# %% [markdown]
# functions with retrun value

# %%
def add(a,b):
  return a+b
n1 = int(input('enter the value'))
n2 = int(input('enter the value'))
result = add(n1,n2)
print('sum =',result)
# Out:
# enter the value10
# enter the value10
# sum = 20

# %%
def mul(a,b):
  return a*b
n1 = int(input('enter the value'))
n2 = int(input('enter the value'))
result = mul(n1,n2)
print('mul = ',result)
# Out:
# enter the value5
# enter the value6
# mul =  30

# %% [markdown]
# lamda functions

# %%
x = lambda a,b : a+b
n1 = int(input("Enter first value: "))
n2 = int(input("Enter second value: "))
print('sum =',x(n1,n2))
# Out:
# Enter first value: 50
# Enter second value: 50
# sum = 100
