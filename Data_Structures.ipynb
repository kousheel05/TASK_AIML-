# %% [markdown]
# <a href="https://colab.research.google.com/github/kousheel05/TASK_AIML-/blob/main/Data_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Stack

# %%
stack = []
stack.append(10)
stack.append(15)
stack.append(19)
stack.append(22)
stack.append(34)
print("stack:" , stack)
stack.pop(3)
print("stack:",stack)
# Out:
# stack: [10, 15, 19, 22, 34]
# stack: [10, 15, 19, 34]

# %% [markdown]
# queue

# %%
queue = []
queue.append(10)
queue.append(20)
queue.append(30)
queue.append(40)
queue.append(50)
print("Queue:", queue)
queue.pop(0)
print("queue:", queue)
# Out:
# Queue: [10, 20, 30, 40, 50]
# queue: [20, 30, 40, 50]

# %%
stack = []

# Add elements using input
n = int(input("How many numbers do you want to add? "))

for i in range(n):
    num = int(input("Enter a number: "))
    stack.append(num)

print("Stack:", stack)

# Remove a specific number
remove_num = int(input("Enter the number to remove: "))

if remove_num in stack:
    stack.remove(remove_num)
    print(remove_num, "removed successfully")
else:
    print("Number not found in stack")

print("Updated Stack:", stack)
# Out:
# How many numbers do you want to add? 4
# Enter a number: 10
# Enter a number: 20
# Enter a number: 30
# Enter a number: 1000000
# Stack: [10, 20, 30, 1000000]
# Enter the number to remove: 500
# Number not found in stack
# Updated Stack: [10, 20, 30, 1000000]

# %%
from collections import deque

queue = deque()

n = int(input("How many numbers? "))

for i in range(n):
    num = int(input("Enter number: "))
    queue.append(num)

print("Queue:", list(queue))

removed = queue.popleft()

print("Removed:", removed)
print("Queue after removal:", list(queue))

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# Create nodes
first = Node(10)
second = Node(20)
third = Node(30)

# Link nodes
first.next = second
second.next = third

# Display linked list
current = first

while current:
    print(current.data, end=" -> ")
    current = current.next

print("None")
